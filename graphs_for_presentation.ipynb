# %% [markdown]
# <a href="https://colab.research.google.com/github/sharma18b/GColab_Deep_Learning/blob/master/graphs_for_presentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/epoch_wise_loss.csv')

# %%
df
# Out:
#     level_0 level_1 level_2    level_3  level_4   level_5  level_6   level_7  \
# 0    Epoch:   1/100   step:     1/4526  Loss-A:  9.460978  Loss-B:  9.737416
# 1    Epoch:   1/100   step:   101/4526  Loss-A:  5.925581  Loss-B:  6.245985
# 2    Epoch:   1/100   step:   201/4526  Loss-A:  5.991248  Loss-B:  6.290869
# 3    Epoch:   1/100   step:   301/4526  Loss-A:  5.605314  Loss-B:  5.937054
# 4    Epoch:   1/100   step:   401/4526  Loss-A:  5.510126  Loss-B:  5.831414
# ..      ...     ...     ...        ...      ...       ...      ...       ...
# 629  Epoch:  14/100   step:  2601/4526  Loss-A:  2.690674  Loss-B:  3.023010
# 630  Epoch:  14/100   step:  2701/4526  Loss-A:  2.686507  Loss-B:  3.013584
# 631  Epoch:  14/100   step:  2801/4526  Loss-A:  3.008312  Loss-B:  3.406236
# 632  Epoch:  14/100   step:  2901/4526  Loss-A:  2.880471  Loss-B:  3.141567
# 633  Epoch:  14/100   step:  3001/4526  Loss-A:  2.780180  Loss-B:  3.225060
#
# ...

# %%
import matplotlib.pyplot as plt
df["level_17"].plot(color='red')
df["level_19"].plot(color='green')
df["level_21"].plot(color='black')
plt.title("Avg Loss A vs B vs C")
plt.xlabel('steps of 100 while training over overall batch size')
plt.ylabel('Loss A - red ,B - Green ,C - Black')
plt.savefig("Avg Loss A vs B vs C.png",dpi=300)
plt.show()

# %%
df["level_24"].plot(color='red')
#df["level_27"].plot(color='green')
#df["level_30"].plot(color='blue')
plt.title("While Training Accuracy Bleu-1 A vs B vs C")
plt.xlabel('steps of 100 while training over overall batch size')
plt.ylabel('Loss A - red ,B - Green ,C - Black')
#plt.savefig("While Training Accuracy Bleu-1 A vs B vs C.png",dpi=300)
plt.show()
